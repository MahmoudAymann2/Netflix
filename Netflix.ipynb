# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
data = pd.read_csv("netfix_cleaned.csv")
data
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
data.describe()
# Out:
#        release_year
# count    560.000000
# mean    2016.521429
# std        6.282517
# min     1993.000000
# 25%     2012.000000
# 50%     2019.000000
# 75%     2022.000000
# max     2023.000000

# %%
data.names
# Out:
# 0                 Mission Majnu
# 1                        Cirkus
# 2           Gangubai Kathiawadi
# 3                       Thunivu
# 4             Bhool Bhulaiyaa 2
#                  ...
# 555              Happy New Year
# 556                 RRR (Hindi)
# 557              Major (Telugu)
# 558                Om Shanti Om
# 559    Kabhi Khushi Kabhie Gham
# Name: names, Length: 560, dtype: object

# %%
data.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# ...

# %%
data.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# ...

# %%
data["names"].describe()
# Out:
# count               560
# unique              245
# top       Chillar Party
# freq                  7
# Name: names, dtype: object

# %%
data.loc[ "200" :  , "genre" : "audio"]
# Out:
#                                                  genre             mood  \
# 200                          ['US Movies', 'Comedies']          Raunchy
# 201  ['Hindi-Language Movies', 'Bollywood Movies', ...            Goofy
# 202  ['Romantic Comedies', 'Hindi-Language Movies',...       Emotional,
# 203  ['Mysteries', 'Family Features', 'US Movies', ...            Goofy
# 204  ['Family Features', 'US Movies', 'Children & F...            Goofy
# ..                                                 ...              ...
# 555  ['Hindi-Language Movies', 'Bollywood Movies', ...        Feel-Good
# 556                   ['Action & Adventure', 'Dramas']  Adrenaline Rush
# 557  ['Movies Based on Real Life', 'Action & Advent...     Bittersweet,
# 558  ['Romantic Comedies', 'Hindi-Language Movies',...       Emotional,
# 559  ['Hindi-Language Movies', 'Bollywood Movies', ...     Sentimental,
#
#                                                   cast              subtitles  \
# ...

# %%
data.iloc[0:3 , 0:4]
# Out:
#                  names  release_year maturity_rating duration
# 0        Mission Majnu          2023        U/A 16+     2h 9m
# 1               Cirkus          2022         U/A 7+    2h 14m
# 2  Gangubai Kathiawadi          2022        U/A 16+    2h 33m

# %%
data.drop(["names","cast","mood"],axis = 1)
# Out:
#      release_year maturity_rating duration  \
# 0            2023        U/A 16+     2h 9m
# 1            2022         U/A 7+    2h 14m
# 2            2022        U/A 16+    2h 33m
# 3            2023        U/A 16+    2h 22m
# 4            2022        U/A 13+    2h 21m
# ..            ...             ...      ...
# 555          2014        U/A 13+    2h 58m
# 556          2022              A     3h 5m
# 557          2022        U/A 16+    2h 25m
# 558          2007        U/A 16+    2h 48m
# 559          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# 1    Chaos and comedy take the spotlight when a rin...
# 2    Duped and sold to a brothel, a young woman fea...
# 3    A major bank heist takes an unnerving turn whe...
# 4    When strangers Reet and Ruhan cross paths, the...
# ..                                                 ...
# ...

# %%
data.drop([1,2,3],axis = 0)
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# 5                    Doctor G          2022        U/A 13+     2h 1m
# 6                   Double XL          2022        U/A 13+     2h 5m
# 7                 Kabir Singh          2019              A    2h 51m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   names            560 non-null    object
#  1   release_year     560 non-null    int64
#  2   maturity_rating  560 non-null    object
#  3   duration         560 non-null    object
#  4   description      560 non-null    object
#  5   genre            560 non-null    object
#  6   mood             517 non-null    object
#  7   cast             560 non-null    object
#  8   subtitles        560 non-null    object
#  9   audio            560 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 43.9+ KB

# %%
data.dtypes
# Out:
# names              object
# release_year        int64
# maturity_rating    object
# duration           object
# description        object
# genre              object
# mood               object
# cast               object
# subtitles          object
# audio              object
# dtype: object

# %%
new_data = data.dropna()
new_data
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
x=['Exciting','Emotional','Adrenaline Rush','Heartfelt','Goofy','Feel-Good','Suspenseful','Goofy','Violent','Witty']
y=  [90,39,32,25,24,19,19,17,17,15]
plt.barh(x,y,color="y")
plt.title("Top moods in netflix")
plt.xlabel("mood")
plt.ylabel("shows")
plt.show()

# %%
x= ['2022','2021','2020','2018','2011','2013','2019','2016','2015','2010']
y= [160,63,35,32,30,28,22,20,20,15]
plt.bar(x,y,color="y",width=0.7)
plt.title("Years with most netflix shows released_year")
plt.xlabel("Year")
plt.ylabel("shows released")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.dropna()
# Out:
#                         names  release_year maturity_rating duration  \
# 0               Mission Majnu          2023        U/A 16+     2h 9m
# 1                      Cirkus          2022         U/A 7+    2h 14m
# 2         Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3                     Thunivu          2023        U/A 16+    2h 22m
# 4           Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
# ..                        ...           ...             ...      ...
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 0    In the 1970s, an undercover Indian spy takes o...
# ...

# %%
data.drop_duplicates()
# Out:
#                                                  names  release_year  \
# 0                                        Mission Majnu          2023
# 1                                               Cirkus          2022
# 2                                  Gangubai Kathiawadi          2022
# 3                                              Thunivu          2023
# 4                                    Bhool Bhulaiyaa 2          2022
# ..                                                 ...           ...
# 538                                   Taare Zameen Par          2007
# 539                                           18 Pages          2022
# 550  Kung-Fu Kings 4: The Challenge of Kung Fu Brot...          2018
# 553                                    Haseen Dillruba          2021
# 559                           Kabhi Khushi Kabhie Gham          2001
#
#     maturity_rating duration  \
# 0          U/A 16+     2h 9m
# 1           U/A 7+    2h 14m
# 2          U/A 16+    2h 33m
# ...

# %%
print(data.size)
# Out:
# 5600

# %%
print(data.shape)
# Out:
# (560, 10)

# %%
data.head()
# Out:
#                  names  release_year maturity_rating duration  \
# 0        Mission Majnu          2023        U/A 16+     2h 9m
# 1               Cirkus          2022         U/A 7+    2h 14m
# 2  Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3              Thunivu          2023        U/A 16+    2h 22m
# 4    Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
#
#                                          description  \
# 0  In the 1970s, an undercover Indian spy takes o...
# 1  Chaos and comedy take the spotlight when a rin...
# 2  Duped and sold to a brothel, a young woman fea...
# 3  A major bank heist takes an unnerving turn whe...
# 4  When strangers Reet and Ruhan cross paths, the...
#
#                                                genre         mood  \
# 0  ['Spy Movies', 'Hindi-Language Movies', 'Bolly...  Suspenseful
# 1  ['Hindi-Language Movies', 'Bollywood Movies', ...        Goofy
# 2  ['Hindi-Language Movies', 'Movies Based on Boo...  Provocative
# ...

# %%
data.tail()
# Out:
#                         names  release_year maturity_rating duration  \
# 555            Happy New Year          2014        U/A 13+    2h 58m
# 556               RRR (Hindi)          2022              A     3h 5m
# 557            Major (Telugu)          2022        U/A 16+    2h 25m
# 558              Om Shanti Om          2007        U/A 16+    2h 48m
# 559  Kabhi Khushi Kabhie Gham          2001        U/A 13+    3h 29m
#
#                                            description  \
# 555  A revenge-seeking diamond thief gathers a ragt...
# 556  A fearless warrior on a perilous mission comes...
# 557  This biopic follows the life of Indian Army of...
# 558  Reincarnated 30 years after being killed in a ...
# 559  Years after his father disowns his adopted bro...
#
#                                                  genre             mood  \
# 555  ['Hindi-Language Movies', 'Bollywood Movies', ...        Feel-Good
# ...

# %%
data.isnull().sum()
# Out:
# names               0
# release_year        0
# maturity_rating     0
# duration            0
# description         0
# genre               0
# mood               43
# cast                0
# subtitles           0
# audio               0
# dtype: int64

# %%
data.hist(figsize=(11,11))
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>]], dtype=object)

# %%
# Plot the correlation matrix
corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

# Step 1: Load and Prepare the Dataset
# Load your Netflix dataset into a pandas DataFrame
df = pd.read_csv('netfix_cleaned.csv')

categorical_columns = df.select_dtypes(include=['object']).columns
categorical_encoder = LabelEncoder()
for audio in categorical_columns:
    df[audio] = categorical_encoder.fit_transform(df[audio])
    
features = df.drop(['audio'], axis=1)
target = df['audio']

# Step 2: Convert Categorical Variables to Numerical Representations
# Perform one-hot encoding for categorical variables in X
categorical_cols = ['names', 'mood'] # List of categorical column names in X
x_encoded = pd.get_dummies(features, columns=categorical_cols)

# Step 3: Preprocess the Dataset
# Standardize the features to have zero mean and unit variance
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_encoded)

# Step 4: Perform LDA
k = 2  # Define the desired number of reduced dimensions
lda = LinearDiscriminantAnalysis(n_components=k)
x_lda = lda.fit_transform(x_scaled, target)

# x_lda contains the reduced-dimensional dataset after applying LDA

# Access the components (projection matrix)
projection_matrix = lda.coef_

# Access the explained variance ratio (amount of variance explained by each component)
explained_variance_ratio = lda.explained_variance_ratio_

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# Load the Netflix dataset
df = pd.read_csv('netfix_cleaned.csv')

# Split dataset into features and labels
x = df['description']  # Features: movie descriptions
y = df['genre']  # Labels: movie genres

# Convert text descriptions into numerical features
vectorizer = CountVectorizer(stop_words='english')
x = vectorizer.fit_transform(x)

# Split dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train Naive Bayes Classifier
clf = MultinomialNB()
clf.fit(x_train, y_train)

# Make predictions on test data
y_pred = clf.predict(x_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 79.46%

# %%
numerical_cols = ['names', 'mood', 'cast', 'genre', 'audio', 'subtitles', 'maturity_rating', 'description', 'duration', 'release_year']
df_numerical = df[numerical_cols]

# Calculate the correlation matrix
corr_matrix = df_numerical.corr()

# Create a heatmap of the correlation matrix
sns.set(style='white')
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
title='Analysis'
content='After seeing the data of Netflix provided things that we can conclude are that firstly, the most popular mood on the netflix is "EXCITING" followed by "EMOTIONAL and ADRENALINE RUSH. Secondly, 2022 was THE year for netflix as it released 160 shows that year and at distant second year is 2021 with 63 shows released. Thirdly, most number of the netflix shows duration was less than 2 hours. Maximum number of shows had a maturity rating of 7+. Chilren & Family shows,US movies,Comedies were most popular genres with having 55 shows. English and Hindi were the most used language in the shows '
print(title)
print(content)
# Out:
# Analysis
# After seeing the data of Netflix provided things that we can conclude are that firstly, the most popular mood on the netflix is "EXCITING" followed by "EMOTIONAL and ADRENALINE RUSH. Secondly, 2022 was THE year for netflix as it released 160 shows that year and at distant second year is 2021 with 63 shows released. Thirdly, most number of the netflix shows duration was less than 2 hours. Maximum number of shows had a maturity rating of 7+. Chilren & Family shows,US movies,Comedies were most popular genres with having 55 shows. English and Hindi were the most used language in the shows

# %%
sns.countplot(data['duration'])
sns.countplot(data['duration']).set_xticklabels(sns.countplot(data['duration']).get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Duration')
# Out:
# C:\Users\Mandoo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mandoo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Mandoo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
data['subtitles'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.show()

# %%
data['audio'] = pd.to_numeric(data['audio'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load Netflix dataset
data = pd.read_csv("netfix_cleaned.csv")

# Print first few rows of the dataset
print(data.head())

# Perform correlation analysis
correlation = data.corr()

# Create a heatmap to visualize the correlation matrix
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation between Attributes in Netflix Dataset")
plt.show()
# Out:
#                  names  release_year maturity_rating duration  \
# 0        Mission Majnu          2023        U/A 16+     2h 9m
# 1               Cirkus          2022         U/A 7+    2h 14m
# 2  Gangubai Kathiawadi          2022        U/A 16+    2h 33m
# 3              Thunivu          2023        U/A 16+    2h 22m
# 4    Bhool Bhulaiyaa 2          2022        U/A 13+    2h 21m
#
#                                          description  \
# 0  In the 1970s, an undercover Indian spy takes o...
# 1  Chaos and comedy take the spotlight when a rin...
# 2  Duped and sold to a brothel, a young woman fea...
# 3  A major bank heist takes an unnerving turn whe...
# 4  When strangers Reet and Ruhan cross paths, the...
#
#                                                genre         mood  \
# 0  ['Spy Movies', 'Hindi-Language Movies', 'Bolly...  Suspenseful
# 1  ['Hindi-Language Movies', 'Bollywood Movies', ...        Goofy
# 2  ['Hindi-Language Movies', 'Movies Based on Boo...  Provocative
# ...

# %%
categorical_columns = data.select_dtypes(include=['object']).columns
categorical_encoder = labelEncoder()
for audio in categorical_columns:
    data[audio] = categorical_encoder.fit_transform(data[audio])
    
features = data.drop(['audio'], axis=1)
target = data['audio']
